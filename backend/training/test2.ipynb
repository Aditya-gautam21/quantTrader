# %%
split_idx_1 = len(data) * (1 - Test_size)
x_train, y_train = train[:split_idx_1], train[split_idx_1:]
x_test, y_test = test[:split_idx_1], test[split_idx_1:]

# %%
split_idx_2 = int(len(x_train) * (1 - (val_size/(1-test_size))))

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
import os
if int(os.environ["COLAB_GPU"]) > 0:
    print("GPU is connected")
elif "COLAB_TPU_ADDR" in os.environ and os.environ["COLAB_TPU_ADDR"]:
    print("TPU is connected")
else:
    print("No accelerator is connected (CPU only)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_897/2382027457.py in <cell line: 0>()
#       1 import os
# ----> 2 if int(os.environ["COLAB_GPU"]) > 0:
#       3     print("GPU is connected")
#       4 elif "COLAB_TPU_ADDR" in os.environ and os.environ["COLAB_TPU_ADDR"]:
#       5     print("TPU is connected")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
torch.FloatTensor()

train_loader = DataLoader(dataset, batchsize, shuffle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_897/2428072582.py in <cell line: 0>()
#       1 torch.FloatTensor()
#       2
# ----> 3 train_loader = DataLoader(dataset, batchsize, shuffle)
#
# NameError: name 'dataset' is not defined

# %%
class NNTraining:
    def __init__(self, input, hidden):
        super().__init__()
